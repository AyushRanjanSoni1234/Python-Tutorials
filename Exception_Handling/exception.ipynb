# %%
### Write a function that takes two integers as input and returns their division. Use try, except, and finally blocks to handle division by zero and print an appropriate message.

# %%
def division(x, y):
    try:
        result = x / y
    except ZeroDivisionError:
        print("Division by zero is not allowed")
    else:
        return result
    finally:
        print("Division operation completed")

# %%
division(10, 0)
# Out:
# Division by zero is not allowed
# Division operation completed

# %%
### Write a function that reads the contents of a file named `data.txt`. Use try, except, and finally blocks to handle file not found errors and ensure the file is properly closed.

def read_file(filename):
    try:
        file = open(filename, 'r')
        content = file.read()
        return content
    except FileNotFoundError as e:
        print(f"Error: {e}")
    finally:
        try:
            file.close()
        except NameError:
            pass

# Test
print(read_file('E:\Work\OneDrive - Rapifuzz Private Limited\Desktop\Ayush\Data_Science\File Handling\data.txt'))
# Out:
# Error: [Errno 2] No such file or directory: 'E:\\Work\\OneDrive - Rapifuzz Private Limited\\Desktop\\Ayush\\Data_Science\\File Handling\\data.txt'
# None
# <>:17: SyntaxWarning: invalid escape sequence '\W'
# <>:17: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\AyushRanjanSoni\AppData\Local\Temp\ipykernel_9344\2304647332.py:17: SyntaxWarning: invalid escape sequence '\W'
#   print(read_file('E:\Work\OneDrive - Rapifuzz Private Limited\Desktop\Ayush\Data_Science\File Handling\data.txt'))

# %%
## Write a function that takes a list of integers and returns their sum. Use try, except, and finally blocks to handle TypeError if a non-integer value is encountered and print an appropriate message.

def sum_list(lst):
    try:
        total = sum(lst)
    except TypeError as e:
        print(f"Error: {e}")
        print("Please provide a list of integers")
    else:
        return total
    finally:
        print("Sum operation completed")

sum_list([1, 2, 3, 4, 5])
# sum_list([1, 2, '3', 4, 5])
# Out:
# Sum operation completed
# 15

# %%
## Write a function that prompts the user to enter an integer. Use try, except, and finally blocks to handle ValueError if the user enters a non-integer value and print an appropriate message.

def get_integer():
    try:
        num = int(input("Enter an integer: "))
    except ValueError:
        print("Error: Please enter an integer")
    else:
        return num
    finally:
        print("Operation completed")        

get_integer()
# Out:
# Error: Please enter an integer
# Operation completed

# %%
## Write a function that takes a dictionary and a key as input and returns the value associated with the key. Use try, except, and finally blocks to handle KeyError if the key is not found in the dictionary and print an appropriate message.

def get_value(dictionary, key):
    try:
        value = dictionary[key]
        return value
    except KeyError:
        print("Error: Key not found in dictionary")
    finally:
        print("Operation completed")

# Test
dictionary = {'a': 1, 'b': 2, 'c': 3}       
get_value(dictionary, 'a')
# get_value(dictionary, 'd')
# Out:
# Operation completed
# 1

# %%
## Write a function that performs nested exception handling. It should first attempt to convert a string to an integer, and then attempt to divide by that integer. Use nested try, except, and finally blocks to handle ValueError and ZeroDivisionError and print appropriate messages.

def nested_exception_handling(string):
    try:
        num = int(string)
        try:
            result = 10 / num
        except ZeroDivisionError:
            print("Error: Division by zero is not allowed")
        else:
            return result
        finally:
            print("Division operation completed")    
    except ValueError:
        print("Error: Please enter a valid integer")
    finally:
        print("Operation completed")

# Test
nested_exception_handling('5')    
# nested_exception_handling('0')   
# nested_exception_handling('a')
# Out:
# Division operation completed
# Operation completed
# 2.0

# %%
## Write a function that takes a list and an index as input and returns the element at the given index. Use try, except, and finally blocks to handle IndexError if the index is out of range and print an appropriate message.

def get_element(lst, index):
    try:
        element = lst[index]
        return element
    except IndexError:
        print("Error: Index out of range")
    finally:
        print("Operation completed")

# Test
# get_element([1, 2, 3, 4, 5], 2)
get_element([1, 2, 3, 4, 5], 10)
# Out:
# Error: Index out of range
# Operation completed

# %%
## Write a function that attempts to open a URL and read its contents. Use try, except, and finally blocks to handle network-related errors and print an appropriate message.

def read_url(url):
    import requests
    try:
        response = requests.get(url)
        return response.text
    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
    finally:
        print("Operation completed")

# Test
# print(read_url('https://www.google.com'))
print(read_url('https://www.google.com/invalid'))
# Out:
# Operation completed
# <!DOCTYPE html>
# <html lang=en>
#   <meta charset=utf-8>
#   <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">
#   <title>Error 404 (Not Found)!!1</title>
#   <style>
# ...

# %%
## Write a function that attempts to parse a JSON string. Use try, except, and finally blocks to handle JSONDecodeError if the string is not a valid JSON and print an appropriate message.

def parse_json(json_string):
    import json
    try:
        data = json.loads(json_string)
        return data
    except json.JSONDecodeError as e:  
        print(f"Error: {e}")
    finally:
        print("Operation completed")

# test 
parse_json('{"a": 1, "b": 2}')
# parse_json('{"a": 1, "b": 2')
# Out:
# Operation completed
# {'a': 1, 'b': 2}

# %%
## Define a custom exception named `NegativeNumberError`. Write a function that raises this exception if a negative number is encountered in a list. Use try, except, and finally blocks to handle the custom exception and print an appropriate message.

def check_negative_number(lst):
    class NegativeNumberError(Exception):
        pass
    try:
        for num in lst:
            if num < 0:
                raise NegativeNumberError("Negative number found in list")
    except NegativeNumberError as e:
        print(f"Error: {e}")
    finally:
        print("Operation completed")            
    
# test
# check_negative_number([1, 2, 3, -4, 5])
check_negative_number([1, 2, 3, 4, 5])
# Out:
# Operation completed

# %%
## Write a function that calls another function which may raise an exception. Use try, except, and finally blocks to handle the exception and print an appropriate message.

def call_function(dict, key):
    try:
        value = get_value(dict, key)
        return value
    except KeyError:
        print("Error: Key not found in dictionary")
    finally:
        print("Operation completed")

# test
call_function({'a': 1, 'b': 2, 'c': 3}, 'c')
# Out:
# Operation completed
# Operation completed
# 3

# %%
## Define a class with a method that performs a division operation. Use try, except, and finally blocks within the method to handle division by zero and print an appropriate message.

class Calculator:
    def divide(self, a, b):
        try:
            result = a / b
        except ZeroDivisionError as e:
            print(f"Error: {e}")
            result = None
        finally:
            print("Execution complete.")
        return result

# Test
calc = Calculator()
# print(calc.divide(10, 2))  # 5.0
print(calc.divide(10, 0))  # None
# Out:
# Error: division by zero
# Execution complete.
# None

# %%
## Write a function that takes a list of strings and converts them to integers. Use try, except, and finally blocks to handle ValueError if a string cannot be converted and print an appropriate message.

def convert_str_to_int(lst):
    try:
        lst1 = []
        for item in lst:
            lst1.append(int(item))
    except ValueError as e:
        print(f'Error : {e}')
    else:
        return lst1    
    finally:
        print('Operation Completed')            

#test
# convert_str_to_int([1,2,3,4,5,6,7,8])        
#convert_str_to_int([1,2,'1',4,'4',6,7,8]) 
convert_str_to_int([1,2,'a',5,6,7,8])
# Out:
# Error : invalid literal for int() with base 10: 'a'
# Operation Completed

# %%
## Write a function that uses a list comprehension to convert a list of strings to integers. Use try, except, and finally blocks within the list comprehension to handle ValueError and print an appropriate message.

def str_to_int(lst):
    try:
        lst1 = [int(item) for item in lst]
    except ValueError as e:
        print(f'Error : {e}')
    else:
        return lst1    
    finally:
        print('Operation Completed')  

# test
# convert_str_to_int([1,2,3,4,5,6,7,8])        
#convert_str_to_int([1,2,'1',4,'4',6,7,8]) 
convert_str_to_int([1,2,'a',5,6,7,8])
# Out:
# Error : invalid literal for int() with base 10: 'a'
# Operation Completed

# %%
## Write a function that attempts to write a list of strings to a file. Use try, except, and finally blocks to handle IOError and ensure the file is properly closed.

def str_file(lst):
    try:
        with open('data.txt', 'w') as f:
            for item in lst:
                if isinstance(item, str):
                    f.write(item +'\n')
                else:
                    raise IOError("There is integer value in a input list")   
    except IOError as e:
        print(f"Error : {e}")            
    finally:
        print('Operation Completed')   

#test
str_file(['Hello', 'World'])
# Out:
# Operation Completed
