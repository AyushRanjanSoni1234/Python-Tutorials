# %%
## Create a class named `Car` with attributes `make`, `model`, and `year`. Create an object of the class and print its attributes.

class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

audi = Car("Audi", "A4", 2020)
print(audi.make)
print(audi.model)   
print(audi.year)
# Out:
# Audi
# A4
# 2020

# %%
dir(Car)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
## Add a method named `start_engine` to the `Car` class that prints a message when the engine starts. Create an object of the class and call the method.

class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def start_engine(self):
        print("Engine started")

audi = Car("Audi", "A4", 2020)
audi.start_engine()
# Out:
# Engine started

# %%
## Create a class named `Student` with attributes `name` and `age`. Use a constructor to initialize these attributes. Create an object of the class and print its attributes.

class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

student = Student("John", 20)
print(student.name)
print(student.age)
# Out:
# John
# 20

# %%
## Create a class named `BankAccount` with private attributes `account_number` and `balance`. Add methods to deposit and withdraw money, and to check the balance. Create an object of the class and perform some operations.

class BankAccount:
    def __init__(self, owner, account_number, balance):
        self.owner = owner
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} is deposited. New balance is {self.balance}")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        else:
            self.balance -= amount  
            print(f"{amount} is withdrawn. New balance is {self.balance}")      

    def check_balance(self):
        print(f"Availabe Balance is {self.balance}")        

account = BankAccount("John", 123456, 1000)
account.deposit(500)
account.withdraw(200)
account.check_balance()
# Out:
# 500 is deposited. New balance is 1500
# 200 is withdrawn. New balance is 1300
# Availabe Balance is 1300

# %%
## Create a base class named `Person` with attributes `name` and `age`. Create a derived class named `Employee` that inherits from `Person` and adds an attribute `employee_id`. Create an object of the derived class and print its attributes.

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def person_details(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")

class Employee(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.employee_id = employee_id

    def employee_details(self):
        self.person_details()
        print(f"Employee ID: {self.employee_id}")

employee = Employee("John", 30, 12345)
employee.employee_details()
# Out:
# Name: John
# Age: 30
# Employee ID: 12345

# %%
## Multiple Inheritance

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def person_details(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")

class Employee():
    def __init__(self,employee_id):
        self.employee_id = employee_id

class PersonDetails(Person, Employee):
    def __init__(self, name, age, employee_id, salary, address):
        Person.__init__(self,name, age)
        Employee.__init__(self,employee_id)
        self.salary = salary
        self.address = address

    def employee_details(self):
        self.person_details()
        print(f"Employee ID: {self.employee_id}")
        print(f"Salary: {self.salary}")
        print(f"Address: {self.address}")


employee = PersonDetails("John", 30, 12345, 50000, "123 Main St")
employee.employee_details()
# Out:
# Name: John
# Age: 30
# Employee ID: 12345
# Salary: 50000
# Address: 123 Main St

# %%
## In the `Employee` class, override the `__str__` method to return a string representation of the object. Create an object of the class and print it.

class Employee(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.employee_id = employee_id

    def __str__(self):
        return f"Employee(Name: {self.name}, Age: {self.age}, Employee ID: {self.employee_id})"
    
employee = Employee("John", 30, 12345)
print(employee)
# Out:
# Employee(Name: John, Age: 30, Employee ID: 12345)

# %%
## Create a class named `Address` with attributes `street`, `city`, and `zipcode`. Create a class named `Person` that has an `Address` object as an attribute. Create an object of the `Person` class and print its address.

class Address:
    def __init__(self, street, city, zipcode):
        self.street = street
        self.city = city
        self.zipcode = zipcode

class Person:
    def __init__(self, name, age, address):
        self.name = name
        self.age = age
        self.address = address

    def person_details(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")
        print(f"Address: {self.address.street}, {self.address.city}, {self.address.zipcode}")    

address = Address("123 Main St", "New York", 10001)
person = Person("John", 30, address)
person.person_details()
# Out:
# Name: John
# Age: 30
# Address: 123 Main St, New York, 10001

# %%
## Create a class named `Counter` with a class variable `count`. Each time an object is created, increment the count. Add a method to get the current count. Create multiple objects and print the count.

class Counter:
    count = 0
    def __init__(self):
        Counter.count += 1

    def get_count(self):
        return Counter.count
    
counter1 = Counter()
counter2 = Counter()
counter3 = Counter()
print(counter3.get_count())
# Out:
# 3

# %%
## Create a class named `MathOperations` with a static method to calculate the square root of a number. Call the static method without creating an object.

class MathOperations:
    # @staticmethod
    def __init__(self, num):
        self.num = num
        
    def square_root(self):
        return self.num ** 0.5

square_root = MathOperations(25)
print(square_root.square_root())
# Out:
# 5.0

# %%
class MathOperations:

    @staticmethod    
    def square_root(num):
        return num ** 0.5
    
print(MathOperations.square_root(25))
# Out:
# 5.0

# %%
## Create a class named `Rectangle` with private attributes `length` and `width`. Use properties to get and set these attributes. Create an object of the class and test the properties.

class Rectangle:
    def __init__(self, length, width):
        self.__length = length  ## private attribute
        self.__width = width    ## private attribute


class Calucation(Rectangle):
    def __init__(self, length, width):
        super().__init__(length, width)

    def area(self):
        return self._Rectangle__length * self._Rectangle__width
        # return self.__length * self.__width

def area_of_rectangle(rectangle):
    return rectangle.area()

rectangle = Calucation(5, 10)
print(area_of_rectangle(rectangle))
# Out:
# 50

# %%
dir(Calucation)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'area']

# %%
## Create a class named `Rectangle` with private attributes `length` and `width`. Use properties to get and set these attributes. Create an object of the class and test the properties.

class Rectangle:
    def __init__(self, length, width):
        self._length = length  ## Protected Access Modifier or Variables 
        self._width = width    ## Protected Access Modifier or Variables 

    def area(self):
        return self._length * self._width

def area_of_rectangle(rectangle):
    return rectangle.area()

rectangle = Rectangle(5, 10)
print(area_of_rectangle(rectangle))
# Out:
# 50

# %%
class Rectangle:
    def __init__(self, length, width):
        self.__length = length  ## private attribute
        self.__width = width    ## private attribute

    @property
    def length(self):
        return self.__length

    @length.setter
    def length(self, value):
        self.__length = value

    @property
    def width(self):
        return self.__width

    @width.setter
    def width(self, value):
        self.__width = value

class Calculation(Rectangle):
    def __init__(self, length, width):
        super().__init__(length, width)

    def area(self):
        return self.__length * self.__width     
    
rectangle = Calculation(5, 10)
print(rectangle.length)
print(rectangle.width)
# print(rectangle.area())
rectangle.length = 15
rectangle.width = 20
print(rectangle.length)
print(rectangle.width)
# Out:
# 5
# 10
# 15
# 20

# %%
class Rectangle:
    def __init__(self, length, width):
        self.__length = length  ## private attribute
        self.__width = width    ## private attribute
    
    def get_length(self):
        return self.__length
    
    def set_length(self, length):
        self.__length = length

    def get_width(self):
        return self.__width

    def set_width(self, width):
        self.__width = width

    def area(self):
        return self.__length * self.__width 


class Calculation(Rectangle):
    def __init__(self, length, width):
        super().__init__(length, width)

rectangle = Calculation(5, 10)
print(rectangle.get_length())
print(rectangle.get_width())
rectangle.set_length(15)
rectangle.set_width(20)
print(rectangle.get_length())
print(rectangle.get_width())
print(rectangle.area())
# Out:
# 5
# 10
# 15
# 20
# 300

# %%
## Create an abstract base class named `Shape` with an abstract method `area`. Create derived classes `Circle` and `Square` that implement the `area` method. Create objects of the derived classes and call the `area` method.

from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

class Square(Shape):
    def __init__(self, side):
        self.side = side  

    def area(self):
        return self.side * self.side

def area_of_shape(shape):
    return shape.area()

circle = Circle(5)
square = Square(4)
print(area_of_shape(circle))
print(area_of_shape(square))
# Out:
# 78.5
# 16

# %%
## Create a class named `Vector` with attributes `x` and `y`. Overload the `+` operator to add two `Vector` objects. Create objects of the class and test the operator overloading.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x+other.x, self.y+other.y)
    def __sub__(self, other):
        return Vector(self.x-other.x, self.y-other.y)
    def __mul__(self, other):
        return Vector(self.x*other.x, self.y*other.y)
    def __truediv__(self, other):
        return Vector(self.x/other.x, self.y/other.y)
    def __str__(self):
        return f"Vector({self.x}, {self.y})"
    def __repr__(self):
        return f"Vector({self.x}, {self.y})"
    def __len__(self):
        return 2
vector = Vector(2, 3)
vector2 = Vector(4, 5)      
print(vector + vector2)  
print(vector - vector2)
print(vector * vector2)
print(vector / vector2)
print(vector.__str__())
print(vector.__repr__())
print(vector.__len__())
print(vector.__add__(vector2))
# Out:
# Vector(6, 8)
# Vector(-2, -2)
# Vector(8, 15)
# Vector(0.5, 0.6)
# Vector(2, 3)
# Vector(2, 3)
# 2
# Vector(6, 8)

# %%
class Complex:
    def __init__(self, real, imag):
        self.real = real
        self.imag = imag

    def __add__(self, other):
        return Complex(self.real + other.real, self.imag + other.imag)

    def __str__(self):
        return f"{self.real} + {self.imag}i"
    
complex1 = Complex(2, 3)
complex2 = Complex(4, 5)
print(complex1 + complex2)
complex3 = complex1 + complex2
print(complex3.__str__())
# Out:
# 6 + 8i
# 6 + 8i

# %%
## Create a custom exception named `InsufficientBalanceError`. In the `BankAccount` class, raise this exception when a withdrawal amount is greater than the balance. Handle the exception and print an appropriate message.

class InsufficientBalanceError(Exception):
    def __init__(self):
        pass

class BankAccount(InsufficientBalanceError):
    def __init__(self, owner, account_number, balance):
        self.owner = owner
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} is deposited. New balance is {self.balance}")

    def withdraw(self, amount):
        try:
            if amount > self.balance:
                raise InsufficientBalanceError("Insufficient funds")
            else:
                self.balance -= amount  
                print(f"{amount} is withdrawn. New balance is {self.balance}") 
        except InsufficientBalanceError as e:
            print("Insufficient funds")             

    def check_balance(self):
        print(f"Availabe Balance is {self.balance}")

account = BankAccount("John", 123456, 1000)
account.deposit(500)
account.withdraw(200)
account.check_balance()
# account.withdraw(2000)  ## This will raise the InsufficientBalanceError
# Out:
# 500 is deposited. New balance is 1500
# 200 is withdrawn. New balance is 1300
# Availabe Balance is 1300

# %%
## Create a class named `FileManager` that implements the context manager protocol to open and close a file. Use this class to read the contents of a file.

import os

os.getcwd()

os.chdir("E:\\Work\\OneDrive - Rapifuzz Private Limited\\Desktop\\Ayush\\Data_Science\\File Handling")
os.getcwd()

class FileManager:
    def __init__(self, filename):
        self.filename = filename

    def open(self):
        try:
            self.file = open(self.filename, 'r')
        except FileNotFoundError:
            print(f"File {self.filename} not found.")
        else:
            print(f"File {self.filename} opened successfully.")        
            return self.file
    def close(self):
        self.file.close()

file = FileManager("merged.txt")
file.open()
# Out:
# File merged.txt opened successfully.
# <_io.TextIOWrapper name='merged.txt' mode='r' encoding='cp1252'>

# %%
## Create a class named `Calculator` with methods to add, subtract, multiply, and divide. Each method should return the object itself to allow method chaining. Create an object and chain multiple method calls.

class Calculator:
    def __init__(self, value=0):
        self.value = value

    def add(self, amount):
        self.value += amount
        return self

    def subtract(self, amount):
        self.value -= amount
        return self

    def multiply(self, amount):
        self.value *= amount
        return self

    def divide(self, amount):
        if amount != 0:
            self.value /= amount
        else:
            print("Cannot divide by zero!")
        return self

# Test
calc = Calculator()
calc.add(10).subtract(3).multiply(2).divide(2)
print(calc.value)  # 7.0
# Out:
# 7.0

# %% [markdown]
# ### Inheritance

# %%
## Create a base class named `Animal` with attributes `name` and `species`. Create a derived class named `Dog` that inherits from `Animal` and adds an attribute `breed`. Create an object of the `Dog` class and print its attributes.

class Animal:
    def __init__(self, name, species):
        self.name = name
        self.species = species

    def animal_details(self):
        print(f"Name: {self.name}")
        print(f"Species: {self.species}")

class Dog(Animal):
    def __init__(self, name, species, breed):
        super().__init__(name, species)
        self.breed = breed

    def dog_details(self):
        self.animal_details()
        print(f"Breed: {self.breed}")        

dog = Dog("Buddy", "Dog", "Golden Retriever")
dog.dog_details()
# Out:
# Name: Buddy
# Species: Dog
# Breed: Golden Retriever

# %%
## In the `Dog` class, override the `__str__` method to return a string representation of the object. Create an object of the class and print it.

class Animal:
    def __init__(self, name, species):
        self.name = name
        self.species = species

    def animal_details(self):
        print(f"Name: {self.name}")
        print(f"Species: {self.species}")

class Dog(Animal):
    def __init__(self, name, species, breed):
        super().__init__(name, species)
        self.breed = breed

    def dog_details(self):
        self.animal_details()
        print(f"Breed: {self.breed}") 

    def __str__(self):
        return f"Dog(Name: {self.name}, Species: {self.species}, Breed: {self.breed})"
              

dog = Dog("Buddy", "Dog", "Golden Retriever")
dog.dog_details()        
dog.__str__()
# Out:
# Name: Buddy
# Species: Dog
# Breed: Golden Retriever
# 'Dog(Name: Buddy, Species: Dog, Breed: Golden Retriever)'

# %%
## In the `Dog` class, add a method named `bark` that prints a barking sound. Create an object of the class and call the method.

class Animal:
    def __init__(self, name, species):
        self.name = name
        self.species = species

    def animal_details(self):
        print(f"Name: {self.name}")
        print(f"Species: {self.species}")

class Dog(Animal):
    def __init__(self, name, species, breed):
        super().__init__(name, species)
        self.breed = breed

    def dog_details(self):
        self.animal_details()
        print(f"Breed: {self.breed}") 

    def bark(self):
        self.dog_details()
        print(f"{self.name} bark like this --- Woof! Woof!")    

dog = Dog("Buddy", "Dog", "Golden Retriever")
dog.bark()
# Out:
# Name: Buddy
# Species: Dog
# Breed: Golden Retriever
# Buddy bark like this --- Woof! Woof!

# %%
# Create a base class named `Walker` with a method `walk` that prints a walking message. 
# Create another base class named `Runner` with a method `run` that prints a running message. 
# Create a derived class named `Athlete` that inherits from both `Walker` and `Runner`. 
# Create an object of the `Athlete` class and call both methods.

class Walker:
    def walk(self):
        print("Walking...") 

class Runner:
    def run(self):
        print("Running...")

class Athlete(Walker, Runner):
    def __init__(self, name):
        self.name = name

    def athlete_details(self):
        self.walk()
        self.run()
        print(f'{self.name} is an athlete and he interested in running and walking.') 

athlete = Athlete("John")
athlete.athlete_details()
# Out:
# Walking...
# Running...
# John is an athlete and he interested in running and walking.

# %%
## In the `Athlete` class, override the `walk` method to print a different message. 
# Create an object of the class and call the `walk` method. Use the `super()` function to call the `walk` method of the `Walker` class.

class Walker:
    def walk(self):
        print("Walking...") 

    def __str__(self):
        self.walk()
        print("This is Walker class.")

class Runner:
    def run(self):
        print("Running...")

class Athlete(Walker, Runner):
    def __init__(self, name):
        self.name = name

    def athlete_details(self):
        self.__str__()
        print(f'{self.name} is an athlete and he interested in running and walking.') 

athlete = Athlete("John")
athlete.athlete_details()
# Out:
# Walking...
# This is Walker class.
# John is an athlete and he interested in running and walking.

# %%
class Athlete(Walker, Runner):
    def walk(self):
        print("Athlete walking...")
        super().walk()

# Test
athlete = Athlete()
athlete.walk()
# Out:
# Athlete walking...
# Walking...

# %%
## In the `Athlete` class, add an attribute `training_hours` and a method `train` that prints the training hours. 
# Create an object of the class and call the method.

class Athlete(Walker, Runner):
    def __init__(self, name, training_hours):
        self.name = name
        self.training_hours = training_hours

    def athlete_details(self):
        self.__str__()
        print(f'{self.name} is an athlete and he interested in running and walking.') 
        print(f'Training hours: {self.training_hours}')

athlete = Athlete("John", 5)
athlete.athlete_details()
# Out:
# Walking...
# This is Walker class.
# John is an athlete and he interested in running and walking.
# Training hours: 5

# %%
## Create a class named `A` with a method `show` that prints a message. 
# Create two derived classes `B` and `C` that inherit from `A` and override the `show` method. 
# Create a class `D` that inherits from both `B` and `C`. 
# Create an object of the `D` class and call the `show` method. Observe the method resolution order.

class A:
    def show(self):
        print("Class A")

class B(A):
    def show(self):
        print("Class B")

class C(A):
    def show(self):
        print("Class C")

class D(B, C):
    def show(self):
        print("Class D")
        # super().show()   
        B.show(self)
        C.show(self)
        # super(D, self).show()  ## This will call the show method of class B     

d = D()
d.show()  # Output: Class D, Class B
# Out:
# Class D
# Class B
# Class C

# %%
## Create a base class named `Shape` with an attribute `color`. 
# Create a derived class named `Circle` that inherits from `Shape` and adds an attribute `radius`. Use the `super()` function to initialize the attributes. 
# Create an object of the `Circle` class and print its attributes.

class Shape:
    def __init__(self, color):
        self.color = color
        print(f"Shape color: {self.color}")

class Circle(Shape):
    def __init__(self, color, radius):
        super().__init__(color)
        self.radius = radius
        print(f"Circle radius: {self.radius}")

circle = Circle("Red", 5)
circle.color
# Out:
# Shape color: Red
# Circle radius: 5
# 'Red'

# %%
## Create a class named `Person` with an attribute `name`. Create a class named `Employee` with an attribute `employee_id`. 
# Create a derived class `Manager` that inherits from both `Person` and `Employee`. Use the `super()` function to initialize the attributes. 
# Create an object of the `Manager` class and print its attributes.

class Person:
    def __init__(self, name):
        self.name = name
        # print(f"Person name: {self.name}")

class Employee:
    def __init__(self, employee_id):
        self.employee_id = employee_id
        # print(f"Employee ID: {self.employee_id}")

class Manager(Person, Employee):
    def __init__(self, name, employee_id):
        super().__init__(name)
        Employee.__init__(self, employee_id)
        print(f"Manager name: {self.name}, Employee ID: {self.employee_id}")

manager = Manager("John", 12345)
print(manager.name)
# Out:
# Manager name: John, Employee ID: 12345
# John

# %%
## Create a class named `Vehicle` with a method `start` that prints a starting message. 
# Create a derived class `Car` that overrides the `start` method to print a different message. Use the `super()` function to call the `start` method of the `Vehicle` class. 
# Create an object of the `Car` class and call the `start` method.

class Vehicle:
    def start(self):
        print("Vehicle starting...")

class Car(Vehicle):
    def start(self):
        print("Car starting...")
        super().start()

car = Car()
car.start()  # Output: Car starting... Vehicle starting...
# Out:
# Car starting...
# Vehicle starting...

# %%
## Create a class named `Flyer` with a method `fly` that prints a flying message. 
# Create a class named `Swimmer` with a method `swim` that prints a swimming message. 
# Create a derived class `Superhero` that inherits from both `Flyer` and `Swimmer`. 
# Create an object of the `Superhero` class and call both methods.

class Flyer:
    def fly(self):
        print("Flying...")

class Swimmer:
    def swim(self):
        print("Swimming...")

class Superhero(Flyer, Swimmer):
    def __init__(self, name):
        self.name = name
    def call(self):
        print(f"Superhero {self.name} is ready to fly and swim!")
        self.fly()
        self.swim()

superhero = Superhero("Superman")
superhero.call()  # Output: Superhero Superman is ready to fly and swim! Flying... Swimming...
# Out:
# Superhero Superman is ready to fly and swim!
# Flying...
# Swimming...

# %%
## Create a class named `Base1` with an attribute `a`. Create a class named `Base2` with an attribute `b`. 
# Create a class named `Derived` that inherits from both `Base1` and `Base2` and adds an attribute `c`. Initialize all attributes using the `super()` function. 
# Create an object of the `Derived` class and print its attributes.

class Base1:
    def __init__(self, a):
        self.a = a
        print(f"Base1 a: {self.a}")

class Base2:
    def __init__(self, b):
        self.b = b
        print(f"Base2 b: {self.b}")

class Derived(Base1, Base2):
    def __init__(self, a, b, c):
        super().__init__(a)
        Base2.__init__(self, b)
        self.c = c
        print(f"Derived c: {self.c}")

derived = Derived(1, 2, 3)
print(derived.a)
print(derived.b)
print(derived.c)
# Out:
# Base1 a: 1
# Base2 b: 2
# Derived c: 3
# 1
# 2
# 3

# %%
## Create a base class named `Animal` and a derived class named `Cat`. 
# Create objects of both classes and use the `isinstance` function to check the instance types.

class Animal:
    def __init__(self, name):
        self.name = name

class Cat(Animal):
    def __init__(self, name, breed):
        super().__init__(name)
        self.breed = breed

animal = Animal("Dog")
cat = Cat("Cat", "Persian")
print(isinstance(animal, Animal))  # Output: True
print(isinstance(cat, Animal))     # Output: True
print(isinstance(cat, Cat))        # Output: True
print(isinstance(animal, Cat))      # Output: False
print(isinstance(cat, object))     # Output: True
print(isinstance(animal, object))  # Output: True

print(animal.name)
print(cat.name)
print(cat.breed)
# Out:
# True
# True
# True
# False
# True
# True
# Dog
# Cat
# Persian

# %%
## Create a base class named `Bird` with a method `speak`. 
# Create two derived classes `Parrot` and `Penguin` that override the `speak` method. 
# Create a list of `Bird` objects and call the `speak` method on each object to demonstrate polymorphism.

class Bird:
    def speak(self):
        print("Bird is chirping...")

class Parrot(Bird):
    def speak(self):
        print("Parrot is speaking...")

class Penguin(Bird):
    def speak(self):
        print("Penguin is making sounds...")

list_of_birds = [Bird(), Parrot(), Penguin()]
for bird in list_of_birds:
    bird.speak()  # Output: Bird is chirping..., Parrot is speaking..., Penguin is making sounds...
# Out:
# Bird is chirping...
# Parrot is speaking...
# Penguin is making sounds...

# %%
## Create a base class named `Device` with an attribute `brand`. 
# Create a derived class `Phone` that inherits from `Device` and adds an attribute `model`. 
# Create another base class `Camera` with an attribute `resolution`. 
# Create a derived class `Smartphone` that inherits from both `Phone` and `Camera`. 
# Create an object of the `Smartphone` class and print its attributes.

class Device:
    def __init__(self, brand):
        self.brand = brand
        print(f"Device brand: {self.brand}")
class Phone(Device):
    def __init__(self, brand, model):
        super().__init__(brand)
        self.model = model
        print(f"Phone model: {self.model}")

class Camera:
    def __init__(self, resolution):
        self.resolution = resolution
        print(f"Camera resolution: {self.resolution}")

class Smartphone(Phone, Camera):
    def __init__(self, brand, model, resolution):
        Phone.__init__(self, brand, model)
        Camera.__init__(self, resolution)
        print(f"Smartphone brand: {self.brand}, model: {self.model}, resolution: {self.resolution}")

smartphone = Smartphone("Samsung", "Galaxy S21", "108MP")
print(smartphone)
# Out:
# Device brand: Samsung
# Phone model: Galaxy S21
# Camera resolution: 108MP
# Smartphone brand: Samsung, model: Galaxy S21, resolution: 108MP
# ...

# %%
## Create a base class named `Shape` with a method `area`. 
# Create two derived classes `Circle` and `Square` that override the `area` method. 
# Create a list of `Shape` objects and call the `area` method on each object to demonstrate polymorphism.

class Shape:
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius
    
class Square(Shape):
    def __init__(self, side):
        self.side = side

    def area(self):
        return self.side * self.side

def area_of_shape(shapes):
    for shape in shapes:
        print(f"Area of {shape} : {shape.area()}")

circle = Circle(5)
square = Square(4)

shapes = [circle, square]
area_of_shape(shapes) # Output: Area of <__main__.Circle object at 0x...> : 78.5, Area of <__main__.Square object at 0x...> : 16
# Out:
# Area of <__main__.Circle object at 0x000002F5F61AD970> : 78.5
# Area of <__main__.Square object at 0x000002F5F61ADE80> : 16

# %%
class Shape:
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

    def __str__(self):
        return f"Circle with radius {self.radius}"

class Square(Shape):
    def __init__(self, side):
        self.side = side

    def area(self):
        return self.side * self.side

    def __str__(self):
        return f"Square with side {self.side}"

def area_of_shape(shapes):
    for shape in shapes:
        print(f"Area of {shape} : {shape.area()}")

circle = Circle(5)
square = Square(4)

shapes = [circle, square]
area_of_shape(shapes)
# Out:
# Area of Circle with radius 5 : 78.5
# Area of Square with side 4 : 16

# %%
## Create a function named `describe_shape` that takes a `Shape` object as an argument and calls its `area` method. 
# Create objects of `Circle` and `Square` classes and pass them to the `describe_shape` function.

def describe_shape(shape):
    print(f"Area of {shape} : {shape.area()}")

describe_shape(circle)
describe_shape(square)
# Out:
# Area of Circle with radius 5 : 78.5
# Area of Square with side 4 : 16

# %%
## Create an abstract base class named `Vehicle` with an abstract method `start_engine`. 
# Create derived classes `Car` and `Bike` that implement the `start_engine` method. 
# Create objects of the derived classes and call the `start_engine` method.

from abc import ABC, abstractmethod
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        print("Car engine started")

class Bike(Vehicle):
    def start_engine(self):
        print("Bike engine started")        

car = Car()
car.start_engine()  # Output: Car engine started
bike = Bike()
bike.start_engine()  # Output: Bike engine started
# Out:
# Car engine started
# Bike engine started

# %%
## In the `Vehicle` class, add a concrete method `fuel_type` that returns a generic fuel type. 
# Override this method in `Car` and `Bike` classes to return specific fuel types. 
# Create objects of the derived classes and call the `fuel_type` method.

class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass
    def fuel_type(self):
        return "Generic fuel type"
    
class Car(Vehicle):
    def start_engine(self):
        print("Car engine started")
    def fuel_type(self):
        return "Generic fuel type : Petrol/Deisel" 

class Bike(Vehicle):
    def start_engine(self):
        print("Bike engine started")
    def fuel_type(self):
        return "Generic fuel type : Petrol"

car = Car()
car.start_engine()  # Output: Car engine started
print(car.fuel_type())  # Output: Petrol/Deisel
bike = Bike()
bike.start_engine()  # Output: Bike engine started
print(bike.fuel_type())  # Output: Petrol
# Out:
# Car engine started
# Generic fuel type : Petrol/Deisel
# Bike engine started
# Generic fuel type : Petrol

# %%
## Create a class named `BankAccount` with private attributes `account_number` and `balance`. 
# Add methods to deposit and withdraw money, and to check the balance. Ensure that the balance cannot be accessed directly.

class BankAccount:
    def __init__(self, account_number, balance):
        self.__account_number = account_number
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount
        print(f"{amount} is deposited. New balance is {self.__balance}")

    def withdraw(self, amount):
        if amount > self.__balance:
            print("Insufficient funds")
        else:
            self.__balance -= amount  
            print(f"{amount} is withdrawn. New balance is {self.__balance}")

    def check_balance(self):
        print(f"Available Balance is {self.__balance}")


account = BankAccount(123456, 1000)
account.deposit(500)
account.withdraw(200)
account.check_balance()
# Out:
# 500 is deposited. New balance is 1500
# 200 is withdrawn. New balance is 1300
# Available Balance is 1300

# %%
## In the `BankAccount` class, use property decorators to get and set the `balance` attribute. 
# Ensure that the balance cannot be set to a negative value.

class BankAccount:
    def __init__(self, account_number, balance = 0):
        self.__account_number = account_number
        self.__balance = balance

    @property
    def balance(self):
        return self.__balance

    @balance.setter
    def balance(self, amount):
        if amount < 0:
            raise ValueError("Balance cannot be negative")
        self.__balance = amount

    def deposit(self, amount):
        self.__balance += amount
        return self.__balance

    def withdraw(self, amount):
        if amount > self.__balance:
            print("Insufficient funds")
        else:
            self.__balance -= amount  
            return self.__balance

# Test
account = BankAccount('12345678', 1000)
print(f'Amount Deposited = {account.deposit(500)}')
print(f'Amount Withdrawn = {account.withdraw(300)}')
print(f'Availabe Balance = {account.balance}')  # 1300
# account.balance = -500  # Balance cannot be negative!
# Out:
# Amount Deposited = 1500
# Amount Withdrawn = 1200
# Availabe Balance = 1200

# %%
## Create a base class named `Person` with private attributes `name` and `age`. Add methods to get and set these attributes. 
# Create a derived class named `Student` that adds an attribute `student_id`. 
# Create an object of the `Student` class and test the encapsulation.

class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age

    @property
    def get_name(self):
        return self.__name    
    
    def set_name(self, name):
        self.__name = name

    def get_age(self):
        return self.__age

    def set_age(self, age):
        self.__age = age

class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.student_id = student_id

    def student_details(self):
        print(f"Name: {self.get_name}")
        print(f"Age: {self.get_age()}")
        print(f"Student ID: {self.student_id}")

student = Student("John", 20, "S12345")
student.student_details()             
student.set_name("Doe")
student.set_age(21)
print('\n')
print("Updated Student Details: ")
student.student_details()
# Out:
# Name: John
# Age: 20
# Student ID: S12345
#
#
# Updated Student Details:
# Name: Doe
# Age: 21
# Student ID: S12345

# %%
## Create a base class named `Animal` with a method `speak`. 
# Create two derived classes `Dog` and `Cat` that override the `speak` method. 
# Create a list of `Animal` objects and call the `speak` method on each object to demonstrate polymorphism.

class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def speak(self):
        print("Dog barks")

class Cat(Animal):
    def speak(self):
        print("Cat meows")

list_of_animals = [Dog(), Cat()]
for animal in list_of_animals:
    animal.speak()  # Output: Dog barks, Cat meows
# Out:
# Dog barks
# Cat meows

# %%
## Create an abstract base class named `Employee` with an abstract method `calculate_salary`. 
# Create two derived classes `FullTimeEmployee` and `PartTimeEmployee` that implement the `calculate_salary` method. 
# Create objects of the derived classes and call the `calculate_salary` method.

from abc import ABC, abstractmethod
class Employee(ABC):
    @abstractmethod
    def calculate_salary(self):
        pass

class FullTimeEmployee(Employee):
    def __init__(self, salary):
        self.salary = salary

    def calculate_salary(self):
        return self.salary

class PartTimeEmployee(Employee):
    def __init__(self, hourly_rate, hours_worked):
        self.hourly_rate = hourly_rate
        self.hours_worked = hours_worked

    def calculate_salary(self):
        return self.hourly_rate * self.hours_worked

fulltimeEmployee = FullTimeEmployee(50000)
parttimeEmployee = PartTimeEmployee(100, 80)
print(f"Full Time Employee Salary: {fulltimeEmployee.calculate_salary()}")
print(f"Part Time Employee Salary: {parttimeEmployee.calculate_salary()}")  # Output: 1600
# Out:
# Full Time Employee Salary: 50000
# Part Time Employee Salary: 8000

# %%
## Create a data class named `Product` with private attributes `product_id`, `name`, and `price`. 
# Add methods to get and set these attributes. Ensure that the price cannot be set to a negative value.

class Product:
    def __init__(self, product_id, name, price):
        self.__product_id = product_id
        self.__name = name
        self.__price = price

    @property
    def get_product_id(self):
        return self.__product_id

    @property
    def get_name(self):
        return self.__name

    @property
    def get_price(self):
        return self.__price

    @get_price.setter
    def set_price(self, price):
        if price < 0:
            raise ValueError("Price cannot be negative")
        self.__price = price

product = Product(1, "Laptop", 1000)
print(f"Product ID: {product.get_product_id}")
print(f"Product Name: {product.get_name}")
print(f"Product Price: {product.get_price}")
# Out:
# Product ID: 1
# Product Name: Laptop
# Product Price: 1000

# %%
product = Product(1, "Laptop", -1000)
print(f"Product ID: {product.get_product_id}")
print(f"Product Name: {product.get_name}")
print(f"Product Price: {product.get_price}")        
# product.set_price = -500  # This will raise a ValueError: Price cannot be negative
# Out:
# Product ID: 1
# Product Name: Laptop
# Product Price: -1000

# %%
## Create a class named `Vector` with attributes `x` and `y`. 
# Overload the `+` operator to add two `Vector` objects. Create objects of the class and test the operator overloading.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __sub__(self, other):
        return Vector(self.x - other.x, self.y - other.y)
    
    def __str__(self):
        return f"Vector({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(4, 5)
result = v1 + v2
print(f"Result of addition: ({result.x}, {result.y})")  # Output: (6, 8)
result = v1 - v2
print(f"Result of subtraction: ({result.x}, {result.y})")  # Output: (-2, -2)
print(v1.__add__(v2))
print(v1.__sub__(v2))
# Out:
# Result of addition: (6, 8)
# Result of subtraction: (-2, -2)
# Vector(6, 8)
# Vector(-2, -2)

# %%
## Create an abstract base class named `Appliance` with an abstract property `power`. 
# Create two derived classes `WashingMachine` and `Refrigerator` that implement the `power` property. 
# Create objects of the derived classes and access the `power` property.

from abc import ABC, abstractmethod
class Appliance(ABC):
    @property
    @abstractmethod
    def power(self):
        pass

class WashingMachine(Appliance):
    def __init__(self, power):
        self._power = power
    @property
    def power(self):
        return self._power    
    
    def __str__(self):
        return f"Washing Machine :"

class Refrigerator(Appliance):
    def __init__(self, power):
        self._power = power

    @property
    def power(self):
        return self._power    

    def __str__(self):
        return f"Refrigerator :"
    
def appliance_power(appliance):
    print(f"Power of {appliance}: {appliance.power}")

washing_machine = WashingMachine(2000)
refrigerator = Refrigerator(1500) 
appliance_power(washing_machine)
appliance_power(refrigerator)
# Out:
# Power of Washing Machine :: 2000
# Power of Refrigerator :: 1500

# %%
## Create a base class named `Account` with private attributes `account_number` and `balance`. 
# Add methods to get and set these attributes. Create a derived class named `SavingsAccount` that adds an attribute `interest_rate`. 
# Create an object of the `SavingsAccount` class and test the encapsulation.

class Account:
    def __init__(self, account_number, balance):
        self.__account_number = account_number
        self.__balance = balance

    @property
    def get_account_number(self):
        return self.__account_number

    @property
    def get_balance(self):
        return self.__balance

    @get_balance.setter
    def set_balance(self, balance):
        if balance < 0:
            raise ValueError("Balance cannot be negative")
        self.__balance = balance

class SavingsAccount(Account):
    def __init__(self, account_number, balance, interest_rate):
        super().__init__(account_number, balance)
        self.interest_rate = interest_rate    

savingsAccount = SavingsAccount(123456, 1000, 5)
print(f"Account Number: {savingsAccount.get_account_number}")
print(f"Account Balance: {savingsAccount.get_balance}")
print(f"Interest Rate: {savingsAccount.interest_rate}")  # Output: 5
# savingsAccount.set_balance = -2000
# Out:
# Account Number: 123456
# Account Balance: 1000
# Interest Rate: 5

# %%
## Create a class named `Flyer` with a method `fly`. Create a class named `Swimmer` with a method `swim`. 
# Create a class named `Superhero` that inherits from both `Flyer` and `Swimmer` and overrides both methods. 
# Create an object of the `Superhero` class and call both methods.

class Flyer:
    def fly(self):
        print("Flying...")

class Swimmer:
    def swim(self):
        print("Swimming...")

class Superhero(Flyer, Swimmer):
    def fly(self):
        print("Superhero flying...")
    def swim(self):
        print("Superhero swimming...")
    def call(self):
        print("Superhero is ready to fly and swim!")
        self.fly()
        self.swim()

superhero = Superhero()
superhero.call()  # Output: Superhero is ready to fly and swim! Superhero flying... Superhero swimming...
# Out:
# Superhero is ready to fly and swim!
# Superhero flying...
# Superhero swimming...

# %%
## Create an abstract base class named `Worker` with an abstract method `work`. 
# Create two derived classes `Engineer` and `Doctor` that implement the `work` method. 
# Create another derived class `Scientist` that inherits from both `Engineer` and `Doctor`. 
# Create an object of the `Scientist` class and call the `work` method.

from abc import ABC, abstractmethod
class Worker(ABC):
    @abstractmethod
    def work(self):
        pass

class Engineer(Worker):
    def work(self):
        print("Engineer is working...")

class Doctor(Worker):
    def work(self):
        print("Doctor is working...") 

class Scientist(Engineer, Doctor):
    def work(self):
        print("Scientist is working...")
        # Engineer.work(self)
        # Doctor.work(self)
        print("Scientist is doing research...")

scientist = Scientist()
scientist.work()  # Output: Scientist is working... Engineer is working... Doctor is working... Scientist is doing research...
# Out:
# Scientist is working...
# Scientist is doing research...

# %%
class Ayush:
    def __init__(self, name):
        self.name = name
    
    def __str__(self):
        return f"Name: {self.name}"
    
    def __repr__(self):
        return f"Name: {self.name}"
    
ayush = Ayush("Ayush")
ayush
# Out:
# Name: Ayush

# %% [markdown]
# THANK YOU
