# %%
## Define a recursive function to calculate the nth Fibonacci number using memoization. Test the function with different inputs.

def fibonacci(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return n*fibonacci(n-1)
    
fibonacci(5)
# Out:
# 120

# %%
def fibonacci(n, memo={}):
    if n in memo:
        return memo[n]
    if n <= 1:
        return n
    memo[n] = fibonacci(n - 1, memo) + fibonacci(n - 2, memo)
    return memo[n]

# Test
print(fibonacci(10))  # 55
print(fibonacci(15))  # 610
# Out:
# 55
# 610

# %%
## Define a function that takes two arguments, a and b, where b is a dictionary with a default value of an empty dictionary. The function should add a new key-value pair to the dictionary and return it. Test the function with different inputs.

def add_to_dict(a, b=None):
    if b is None:
        b = {}
    b[a] = a**2
    return b

# Test
print(add_to_dict(2))  # {2: 4}
print(add_to_dict(3, {1: 1}))  # {1: 1, 3: 9}
# Out:
# {2: 4}
# {1: 1, 3: 9}

# %%
## Define a function that takes a variable number of keyword arguments and returns a dictionary containing only those key-value pairs where the value is an integer. Test the function with different inputs.

def filter_integers(**kwargs):
    return {k: v for k, v in kwargs.items() if isinstance(v, int)}

print(filter_integers(a=1, b='two', c=3))  # {'a': 1, 'c': 3}
# Out:
# {'a': 1, 'c': 3}

# %%
## Define a function that takes another function as a callback and a list of integers. The function should apply the callback to each integer in the list and return a new list with the results. Test with different callback functions.

def apply_callback(callback, lst):
    lst = [callback(item) for item in lst]
    return lst

# Test
def square(x):
    return x ** 2

def cube(x):
    return x ** 3

print(apply_callback(square, [1, 2, 3]))  # [1, 4, 9]
print(apply_callback(cube, [1, 2, 3]))  # [1, 8, 27]
# Out:
# [1, 4, 9]
# [1, 8, 27]

# %%
## Define a function that calculates the time taken to execute another function. Apply this decorator to a function that performs a complex calculation. Test the decorated function with different inputs.

import time

def time_it(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print(f'Time taken: {end - start:.2f} seconds')
        return result
    return wrapper

@time_it
def complex_calculation(n):
    return sum(range(n))        

# Test
complex_calculation(1000000)  # Time taken: 0.03 seconds
# Out:
# Time taken: 0.02 seconds
# 499999500000

# %%
time_it(complex_calculation(1000000))
# Out:
# Time taken: 0.03 seconds
# <function __main__.time_it.<locals>.wrapper(*args, **kwargs)>

# %%
@time_it
def complex_calculation(n):
    return sum(range(n))

# %%
complex_calculation(1000000)
# Out:
# Time taken: 0.02 seconds
# 499999500000

# %%
## Define a higher-order function that takes two functions, a filter function and a map function, along with a list of integers. The higher-order function should first filter the integers using the filter function and then apply the map function to the filtered integers. Test with different filter and map functions.

def filter_map(filter_func, map_func, lst):
    filter_map_stored = list(map(map_func,list(filter(filter_func, lst))))
    return filter_map_stored

# Test
def is_even(x):
    return x % 2 == 0   

def square(x):
    return x ** 2

def cube(x):    
    return x ** 3

filter_map(is_even, square, [1, 2, 3, 4, 5])  # [4, 16]
# Out:
# [4, 16]

# %%
## Define a function that composes two functions, f and g, such that the result is f(g(x)). Test with different functions f and g.

def compose(f, g):
    return lambda x: f(g(x))

# Test
def square(x):
    return x ** 2

def add_one(x):
    return x + 1

square_add_one = compose(square, add_one)
square_add_one(3)  # 16
# Out:
# 16

# %%
## Use the functools.partial function to create a new function that multiplies its input by 2. Test the new function with different inputs.

from functools import partial

def multiply(a, b):
    return a * b

double = partial(multiply, 2)
print(double(3))  # 6

def exponent(a, b):
    return a ** b

exp = partial(exponent, 3)
print(exp(7))  # 16
# Out:
# 6
# 2187

# %%
def login(func):
    def wrapper(*args, **kwargs):
        if kwargs.get('password') == 'secret':
            return func(*args, **kwargs)
        else:
            return 'Access denied'
    return wrapper

@login
def secure_function(*args, **kwargs):
    return 'Access granted'

# Test
secure_function(password='secret')  #
# Out:
# 'Access granted'

# %%
## Define a function that takes a list of integers and returns their average. The function should handle any errors that occur (e.g., empty list) and return None in such cases. Test with different inputs.

def average(lst):
    if not lst:
        return None 
    sum = 0
    for item in lst:
        sum += item
    return sum / len(lst)    

    # try:
    #     return sum(lst) / len(lst)
    # except ZeroDivisionError:
    #     return None

# Test
print(average([1, 2, 3]))  # 2.0
print(average([]))  # None
# Out:
# 2.0
# None

# %%
## Define a function that generates an infinite sequence of Fibonacci numbers. Test by printing the first 10 numbers in the sequence.

def fibonacci(n):
    a, b = 0, 1
    count = 0
    lst = []
    while count < n:
        yield a
        lst.append(a)
        a, b = b, a + b
        count += 1   

# Test
list(fibonacci(10))

for i, num in enumerate(fibonacci(10)):
    print(f'Fibonacci {i + 1}: {num}')
# Out:
# Fibonacci 1: 0
# Fibonacci 2: 1
# Fibonacci 3: 1
# Fibonacci 4: 2
# Fibonacci 5: 3
# Fibonacci 6: 5
# Fibonacci 7: 8
# Fibonacci 8: 13
# Fibonacci 9: 21
# Fibonacci 10: 34

# %%
## Define a curried function that takes three arguments, one at a time, and returns their product. Test the function by providing arguments one at a time.

def curried_product(a):
    def inner(b):
        def innermost(c):
            return a * b * c
        return innermost
    return inner

# Test
curried_product(2)(3)(4) # 24
# Out:
# 24

# %%
## Define a function that uses a context manager to write a list of integers to a file. The function should handle any errors that occur during file operations. Test with different lists.

def write_to_file(lst, filename):
    try:
        with open(filename, 'w') as file:
            for item in lst:
                if not isinstance(item, int):
                    raise ValueError('All items in the list must be integers')
                else:
                    file.write(f'{item}\n')
    except IOError as e:
        return f'Error writing to file: {e}'
    return 'File written successfully'

# Test
print(write_to_file([1, 2, 3], 'numbers.txt'))  # File written successfully
# print(write_to_file([1, 'Two', 3], 'numbers.txt'))  # Error writing to file: not all arguments converted during string formatting
# Out:
# File written successfully

# %%
## Define a function that takes a list of mixed data types (integers, strings, and floats) and returns three lists: one containing all the integers, one containing all the strings, and one containing all the floats. Test with different inputs.

def data_types_cat_seprator(lst):
    integers = [item for item in lst if isinstance(item, int)]
    strings = [item for item in lst if isinstance(item, str)]
    floats = [item for item in lst if isinstance(item, float)]
    return integers, strings, floats

# Test
integers, strings, floats = data_types_cat_seprator([1, 'Two', 3.0, 4, 'Five', 6.0])  # ([1, 4], ['Two', 'Five'], [3.0, 6.0])
print(f'Integer List = {integers}')
print(f'String List = {strings}')
print(f'Float List = {floats}')
# Out:
# Integer List = [1, 4]
# String List = ['Two', 'Five']
# Float List = [3.0, 6.0]

# %%
## Define a function that maintains state between calls using a mutable default argument. The function should keep track of how many times it has been called. Test by calling the function multiple times.

def call_counter(counter={'count': 0}):
    counter['count'] += 1
    return counter['count']

# Test
print(call_counter())  # 1
print(call_counter())  # 2
print(call_counter())  # 3
# Out:
# 1
# 2
# 3

# %%
def call_count(counts = {'count': 0}):
    counts['count'] = counts['count'] + 1
    return counts['count']

call_count()
call_count()

for _ in range(5):
    print(call_count())
# Out:
# 3
# 4
# 5
# 6
# 7
