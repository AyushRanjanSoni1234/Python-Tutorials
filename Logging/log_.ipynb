# %% [markdown]
# ## Logging Excercise...

# %% [markdown]
# ### Assignment 1: Basic Logging

# %%
import logging as log
import os

# %%
## Write a Python function to create a basic logger that logs messages to a file named `app.log`.

def create_logger():
    log.basicConfig(
        filename='app.log',
        level=log.DEBUG,
        format='%(asctime)s - %(levelname)s - %(message)s'
    )
    logger = log.getLogger()
    logger.setLevel(log.DEBUG)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')
    return logger

# test
create_logger()
# Out:
# <RootLogger root (DEBUG)>

# %%
## Logging/Module_Logging_Assignments_Questions/Module_Logging_Assignments_Questions.ipynb

def logger_with_handlers():
    logger = log.getLogger('my_logger')
    logger.setLevel(log.DEBUG)
    
    file_handler = log.FileHandler('app.log')
    console_handler = log.StreamHandler()
    
    file_handler.setLevel(log.DEBUG)
    console_handler.setLevel(log.DEBUG)
    
    formatter = log.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_handlers()
# Out:
# 2025-05-05 14:27:56,015 - my_logger - DEBUG - This is a debug message
# 2025-05-05 14:27:56,016 - my_logger - INFO - This is an info message
# 2025-05-05 14:27:56,018 - my_logger - WARNING - This is a warning message
# 2025-05-05 14:27:56,019 - my_logger - ERROR - This is an error message
# 2025-05-05 14:27:56,019 - my_logger - CRITICAL - This is a critical message

# %% [markdown]
# ### Logging with Different Handlers

# %%
## Write a Python function to create a logger that logs messages to both a file named `app.log` and the console.

def logger_with_file_and_console():
    logger = log.getLogger('my_logger')
    logger.setLevel(log.DEBUG)
    
    file_handler = log.FileHandler('app.log')
    console_handler = log.StreamHandler()
    
    file_handler.setLevel(log.DEBUG)
    console_handler.setLevel(log.DEBUG)
    
    formatter = log.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_file_and_console()
# Out:
# 2025-05-05 14:35:14,743 - my_logger - DEBUG - This is a debug message
# 2025-05-05 14:35:14,743 - my_logger - DEBUG - This is a debug message
# 2025-05-05 14:35:14,746 - my_logger - INFO - This is an info message
# 2025-05-05 14:35:14,746 - my_logger - INFO - This is an info message
# 2025-05-05 14:35:14,748 - my_logger - WARNING - This is a warning message
# 2025-05-05 14:35:14,748 - my_logger - WARNING - This is a warning message
# 2025-05-05 14:35:14,749 - my_logger - ERROR - This is an error message
# 2025-05-05 14:35:14,749 - my_logger - ERROR - This is an error message
# 2025-05-05 14:35:14,752 - my_logger - CRITICAL - This is a critical message
# 2025-05-05 14:35:14,752 - my_logger - CRITICAL - This is a critical message

# %% [markdown]
# ### Formatting Log Messages

# %%
## Write a Python function to create a logger with a custom log message format that includes the timestamp, logging level, and message.

def logger_with_custom_format():

    logger = log.getLogger('my_logger')
    logger.setLevel(log.DEBUG)

    file_handler = log.FileHandler('app.log')
    console_handler = log.StreamHandler()

    file_handler.setLevel(log.DEBUG)
    console_handler.setLevel(log.DEBUG)

    formatter = log.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)

    logger.addHandler(file_handler)
    logger.addHandler(console_handler)

    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')
# Test the function
logger_with_custom_format()
# Out:
# 2025-05-05 14:40:33,709 - my_logger - DEBUG - This is a debug message
# 2025-05-05 14:40:33,709 - my_logger - DEBUG - This is a debug message
# 2025-05-05 14:40:33,709 - DEBUG - This is a debug message
# 2025-05-05 14:40:33,712 - my_logger - INFO - This is an info message
# 2025-05-05 14:40:33,712 - my_logger - INFO - This is an info message
# 2025-05-05 14:40:33,712 - INFO - This is an info message
# 2025-05-05 14:40:33,713 - my_logger - WARNING - This is a warning message
# 2025-05-05 14:40:33,713 - my_logger - WARNING - This is a warning message
# 2025-05-05 14:40:33,713 - WARNING - This is a warning message
# 2025-05-05 14:40:33,717 - my_logger - ERROR - This is an error message
# 2025-05-05 14:40:33,717 - my_logger - ERROR - This is an error message
# 2025-05-05 14:40:33,717 - ERROR - This is an error message
# 2025-05-05 14:40:33,718 - my_logger - CRITICAL - This is a critical message
# 2025-05-05 14:40:33,718 - my_logger - CRITICAL - This is a critical message
# 2025-05-05 14:40:33,718 - CRITICAL - This is a critical message

# %%
## Modify the function to use different formats for the file and console handlers.

def logger_with_different_formats():
    logger = log.getLogger('multi_format_logger')
    logger.setLevel(log.DEBUG)

    filehandler = log.FileHandler('multi_format_logger.log')
    console = log.StreamHandler()

    filehandler.setLevel(log.DEBUG)
    console.setLevel(log.DEBUG)

    file_formatter = log.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    console_formatter = log.Formatter('%(levelname)s - %(message)s')

    filehandler.setFormatter(file_formatter)
    console.setFormatter(console_formatter)

    logger.addHandler(filehandler)
    logger.addHandler(console)

    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_different_formats()
# Out:
# DEBUG - This is a debug message
# INFO - This is an info message
# WARNING - This is a warning message
# ERROR - This is an error message
# CRITICAL - This is a critical message
